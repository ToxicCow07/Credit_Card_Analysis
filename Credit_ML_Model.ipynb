# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.preprocessing import  StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.metrics import  classification_report, confusion_matrix

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier, AdaBoostClassifier
from sklearn.svm import SVC

# %%
credit= pd.read_csv(r"C:\Users\91798\Downloads\Datasets\Credit_card.csv")
credit.head(5)
# Out:
#     Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0  5008827      M         Y             Y         0       180000.0
# 1  5009744      F         Y             N         0       315000.0
# 2  5009746      F         Y             N         0       315000.0
# 3  5009749      F         Y             N         0            NaN
# 4  5009752      F         Y             N         0       315000.0
#
#             Type_Income         EDUCATION Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
#
#    Birthday_count  Employed_days  Mobile_phone  Work_Phone  Phone  EMAIL_ID  \
# ...

# %%
print(credit.shape)
# Out:
# (1548, 19)

# %%
credit.describe()
# Out:
#              Ind_ID     CHILDREN  Annual_income  Birthday_count  \
# count  1.548000e+03  1548.000000   1.525000e+03     1526.000000
# mean   5.078920e+06     0.412791   1.913993e+05   -16040.342071
# std    4.171759e+04     0.776691   1.132530e+05     4229.503202
# min    5.008827e+06     0.000000   3.375000e+04   -24946.000000
# 25%    5.045070e+06     0.000000   1.215000e+05   -19553.000000
# 50%    5.078842e+06     0.000000   1.665000e+05   -15661.500000
# 75%    5.115673e+06     1.000000   2.250000e+05   -12417.000000
# max    5.150412e+06    14.000000   1.575000e+06    -7705.000000
#
#        Employed_days  Mobile_phone   Work_Phone        Phone     EMAIL_ID  \
# count    1548.000000        1548.0  1548.000000  1548.000000  1548.000000
# mean    59364.689922           1.0     0.208010     0.309432     0.092377
# std    137808.062701           0.0     0.406015     0.462409     0.289651
# min    -14887.000000           1.0     0.000000     0.000000     0.000000
# ...

# %%
credit.isna().sum()
# Out:
# Ind_ID               0
# GENDER               7
# Car_Owner            0
# Propert_Owner        0
# CHILDREN             0
# Annual_income       23
# Type_Income          0
# EDUCATION            0
# Marital_status       0
# Housing_type         0
# Birthday_count      22
# Employed_days        0
# Mobile_phone         0
# Work_Phone           0
# Phone                0
# EMAIL_ID             0
# Type_Occupation    488
# Family_Members       0
# Labels               0
# dtype: int64

# %%
credit.drop('Type_Occupation',axis=1)
# Out:
#        Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0     5008827      M         Y             Y         0       180000.0
# 1     5009744      F         Y             N         0       315000.0
# 2     5009746      F         Y             N         0       315000.0
# 3     5009749      F         Y             N         0            NaN
# 4     5009752      F         Y             N         0       315000.0
# ...       ...    ...       ...           ...       ...            ...
# 1543  5028645      F         N             Y         0            NaN
# 1544  5023655      F         N             N         0       225000.0
# 1545  5115992      M         Y             Y         2       180000.0
# 1546  5118219      M         Y             N         0       270000.0
# 1547  5053790      F         Y             Y         0       225000.0
#
#                Type_Income                      EDUCATION  \
# 0                Pensioner               Higher education
# ...

# %%
credit.dropna(inplace=True)

# %%
Gender=pd.get_dummies(credit['GENDER'],drop_first=True,dtype=float)
Gender.head()
# Out:
#       M
# 8   1.0
# 9   1.0
# 10  1.0
# 11  0.0
# 13  0.0

# %%
C_Owner=pd.get_dummies(credit['Car_Owner'],drop_first=True,dtype=float)
C_Owner.head()
# Out:
#       Y
# 8   1.0
# 9   1.0
# 10  1.0
# 11  1.0
# 13  1.0

# %%
P_Owner=pd.get_dummies(credit['Propert_Owner'],drop_first=True,dtype=float)
P_Owner.head()
# Out:
#       Y
# 8   1.0
# 9   1.0
# 10  1.0
# 11  1.0
# 13  1.0

# %%
credit.drop(['Type_Income','EDUCATION','Marital_status','Housing_type','Birthday_count','Employed_days','GENDER','Ind_ID','Car_Owner','Propert_Owner','Type_Occupation'],axis=1,inplace=True)

# %%
credit.head()
# Out:
#     CHILDREN  Annual_income  Mobile_phone  Work_Phone  Phone  EMAIL_ID  \
# 8          1       450000.0             1           0      1         1
# 9          1       450000.0             1           0      1         1
# 10         1       450000.0             1           0      1         1
# 11         0        90000.0             1           1      1         0
# 13         0        90000.0             1           1      1         0
#
#     Family_Members  Labels
# 8                3       1
# 9                3       1
# 10               1       1
# 11               2       1
# 13               2       1

# %%
credit=pd.concat([credit,Gender,P_Owner,C_Owner],axis=1)

# %%
credit.head()
# Out:
#     CHILDREN  Annual_income  Mobile_phone  Work_Phone  Phone  EMAIL_ID  \
# 8          1       450000.0             1           0      1         1
# 9          1       450000.0             1           0      1         1
# 10         1       450000.0             1           0      1         1
# 11         0        90000.0             1           1      1         0
# 13         0        90000.0             1           1      1         0
#
#     Family_Members  Labels    M    Y    Y
# 8                3       1  1.0  1.0  1.0
# 9                3       1  1.0  1.0  1.0
# 10               1       1  1.0  1.0  1.0
# 11               2       1  0.0  1.0  1.0
# 13               2       1  0.0  1.0  1.0

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1025 entries, 8 to 1546
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CHILDREN        1025 non-null   int64
#  1   Annual_income   1025 non-null   float64
#  2   Mobile_phone    1025 non-null   int64
#  3   Work_Phone      1025 non-null   int64
#  4   Phone           1025 non-null   int64
#  5   EMAIL_ID        1025 non-null   int64
#  6   Family_Members  1025 non-null   int64
#  7   Labels          1025 non-null   int64
#  8   M               1025 non-null   float64
#  9   Y               1025 non-null   float64
#  10  Y               1025 non-null   float64
# dtypes: float64(4), int64(7)
# memory usage: 96.1 KB

# %%
x=credit.drop(['Labels'],axis=1)
y=credit['Labels']

# %%
x
# Out:
#       CHILDREN  Annual_income  Mobile_phone  Work_Phone  Phone  EMAIL_ID  \
# 8            1       450000.0             1           0      1         1
# 9            1       450000.0             1           0      1         1
# 10           1       450000.0             1           0      1         1
# 11           0        90000.0             1           1      1         0
# 13           0        90000.0             1           1      1         0
# ...        ...            ...           ...         ...    ...       ...
# 1540         1       144000.0             1           0      0         0
# 1542         1       360000.0             1           0      1         0
# 1544         0       225000.0             1           0      0         0
# 1545         2       180000.0             1           0      0         0
# 1546         0       270000.0             1           1      1         0
#
#       Family_Members    M    Y    Y
# 8                  3  1.0  1.0  1.0
# ...

# %%
scaler=StandardScaler()
scaler.fit(x)
scaler.transform(x)
# Out:
# array([[ 0.59874351,  2.05752951,  0.        , ...,  1.19537022,
#          0.75158865,  1.15305917],
#        [ 0.59874351,  2.05752951,  0.        , ...,  1.19537022,
#          0.75158865,  1.15305917],
#        [ 0.59874351,  2.05752951,  0.        , ...,  1.19537022,
#          0.75158865,  1.15305917],
#        ...,
#        [-0.58602888,  0.2049344 ,  0.        , ..., -0.83656091,
#         -1.33051504, -0.86725818],
#        [ 1.7835159 , -0.16558463,  0.        , ...,  1.19537022,
#          0.75158865,  1.15305917],
#        [-0.58602888,  0.57545342,  0.        , ...,  1.19537022,
#         -1.33051504,  1.15305917]])

# %%
x_train, x_test, y_train, y_test= train_test_split(x,y,test_size=0.2, random_state= 10)

# %%
models = {
    'Logistic Regression': LogisticRegression(max_iter=1000),
    'SVM': SVC(),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier()
}
accuracy_results = {}
for name, model in models.items():
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)
    accuracy_results[name] = accuracy

print(accuracy_results)
# Out:
# {'Logistic Regression': 0.9170731707317074, 'SVM': 0.9170731707317074, 'Decision Tree': 0.8829268292682927, 'Random Forest': 0.9121951219512195}

# %%
classification_report(y_test,y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.95      0.96      0.95       188\n           1       0.47      0.41      0.44        17\n\n    accuracy                           0.91       205\n   macro avg       0.71      0.68      0.69       205\nweighted avg       0.91      0.91      0.91       205\n'

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[180,   8],
#        [ 10,   7]], dtype=int64)
